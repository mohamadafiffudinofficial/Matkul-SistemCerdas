# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('D:/Kuliah/SISTEM-CERDAS/dataset_soal01.xlsx')

# %%
data.shape
# Out:
# (51, 5)

# %%
data['Class (buy_computer)'].value_counts()
# Out:
# Yes    29
# No     22
# Name: Class (buy_computer), dtype: int64

# %%
PYes = 29/51
PNo = 22/51

# %%
print(PYes)
# Out:
# 0.5686274509803921

# %%
print(PNo)
# Out:
# 0.43137254901960786

# %%
pd.crosstab(data['Student'], data['Class (buy_computer)'])
# Out:
# Class (buy_computer)  No  Yes
# Student
# No                    10   14
# Yes                   12   15

# %%
PbukanmuridNo = 10/22
PmuridNo = 12/22

PbukanmuridYes = 14/29
PmuridYes = 15/29

Pmurid = 27/51
Pbukanmurid = 24/51

print(PmuridYes)
# Out:
# 0.5172413793103449

# %%
PNomurid = (PmuridNo*PNo)/Pmurid
print(PNomurid)
# Out:
# 0.4444444444444444

# %%
PYesmurid = (PmuridYes*PYes)/Pmurid
print(PYesmurid)
# Out:
# 0.5555555555555556

# %%
print(PNomurid)
print(PYesmurid)
# Out:
# 0.4444444444444444
# 0.5555555555555556

# %%
pd.crosstab(data['Income'], data['Class (buy_computer)'])
# Out:
# Class (buy_computer)  No  Yes
# Income
# High                   6    5
# Low                   11   10
# Medium                 5   14

# %%
PHighNo = 6/22
PLowNo = 11/22
PMediumNo = 5/22

PHighYes = 5/29
PLowYes = 10/29
PMediumYes = 14/29

PHigh = 11/51
PLow = 21/51
PMedium = 19/51

# %%
PNoBuy = ((PmuridNo*PLowNo)*PNo)/(Pmurid*PLow)
print(PNoBuy)
# Out:
# 0.5396825396825398

# %%
PBuy = ((PmuridYes*PLowYes)*PYes)/(Pmurid*PLow)
print(PBuy)
# Out:
# 0.46524356869184463

# %%
PSum = PNoBuy+PBuy
print(PSum)
# Out:
# 1.0049261083743843

# %%
PBuy= (PBuy/PSum)*100
print(PBuy)
# Out:
# 46.296296296296305

# %%
PNoBuy = (PNoBuy*PSum)*100
print(PNoBuy)
# Out:
# 54.23410743607789
