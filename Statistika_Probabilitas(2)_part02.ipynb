# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
from scipy.stats import norm

# %%
p = [2, 4, 4, 4, 5, 5, 7, 9]

# %%
plt.hist(p)
plt.title("histogram")
std = np.std(p)
mean = np.mean(p)
plt.plot(norm.pdf(p, mean,std))
plt.show()
